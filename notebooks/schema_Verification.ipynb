# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN merchai_data;

# %% [markdown]
# ## Schemas are created

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS merchai_data.bronze;

CREATE SCHEMA IF NOT EXISTS merchai_data.silver;

CREATE SCHEMA IF NOT EXISTS merchai_data.gold;
